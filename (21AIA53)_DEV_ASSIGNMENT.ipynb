# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("passengers.csv")

# %%
ml = df.head(1000)

# %%
ml.head()
# Out:
#      data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0  05-01-2014  2014      5       14492     RDU       36      11032    CUN
# 1  06-01-2007  2007      6       13204     MCO       33      16085    YHZ
# 2  12-01-2005  2005     12       11433     DTW       43      10411    AUA
# 3  04-01-2003  2003      4       13487     MSP       63      16304    ZIH
# 4  12-01-2005  2005     12       12016     GUM        5      11138    CRK
#
#    fg_wac  airlineid carrier  carriergroup        type  Scheduled  Charter  \
# 0     148      19534      AM             0  Passengers          0      315
# 1     951      20364      C6             0  Passengers          0      683
# 2     277      20344      RD             1  Passengers          0     1010
# 3     148      20204      MG             1  Passengers          0      508
# 4     766      20312      TZ             1  Passengers          0       76
#
#    Total
# 0    315
# 1    683
# 2   1010
# 3    508
# 4     76

# %%
ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data_dte      1000 non-null   object
#  1   Year          1000 non-null   int64
#  2   Month         1000 non-null   int64
#  3   usg_apt_id    1000 non-null   int64
#  4   usg_apt       1000 non-null   object
#  5   usg_wac       1000 non-null   int64
#  6   fg_apt_id     1000 non-null   int64
#  7   fg_apt        1000 non-null   object
#  8   fg_wac        1000 non-null   int64
#  9   airlineid     1000 non-null   int64
#  10  carrier       982 non-null    object
#  11  carriergroup  1000 non-null   int64
#  12  type          1000 non-null   object
#  13  Scheduled     1000 non-null   int64
#  14  Charter       1000 non-null   int64
#  15  Total         1000 non-null   int64
# dtypes: int64(11), object(5)
# memory usage: 125.1+ KB

# %%
ml.describe()
# Out:
#              Year        Month   usg_apt_id      usg_wac     fg_apt_id  \
# count  1000.00000  1000.000000   1000.00000  1000.000000   1000.000000
# mean   2005.31800     6.195000  13061.77200    41.903000  13536.795000
# std       2.83671     3.603604   4990.41416    24.557497   2029.651309
# min    2001.00000     1.000000  10135.00000     1.000000  10148.000000
# 25%    2003.00000     3.000000  11433.00000    23.000000  11503.750000
# 50%    2005.00000     6.000000  13198.00000    34.000000  13605.000000
# 75%    2008.00000    10.000000  13930.00000    63.000000  15513.000000
# max    2014.00000    12.000000  99999.00000    93.000000  16322.000000
#
#             fg_wac     airlineid  carriergroup  Scheduled       Charter  \
# count  1000.000000   1000.000000   1000.000000     1000.0   1000.000000
# mean    431.225000  20276.240000      0.671000        0.0    947.464000
# std     304.111746    385.588583      0.470085        0.0   1836.175563
# ...

# %%
ml.info("month")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data_dte      1000 non-null   object
#  1   Year          1000 non-null   int64
#  2   Month         1000 non-null   int64
#  3   usg_apt_id    1000 non-null   int64
#  4   usg_apt       1000 non-null   object
#  5   usg_wac       1000 non-null   int64
#  6   fg_apt_id     1000 non-null   int64
#  7   fg_apt        1000 non-null   object
#  8   fg_wac        1000 non-null   int64
#  9   airlineid     1000 non-null   int64
#  10  carrier       982 non-null    object
#  11  carriergroup  1000 non-null   int64
#  12  type          1000 non-null   object
#  13  Scheduled     1000 non-null   int64
#  14  Charter       1000 non-null   int64
#  15  Total         1000 non-null   int64
# dtypes: int64(11), object(5)
# memory usage: 125.1+ KB

# %%
ml.shape
# Out:
# (1000, 16)

# %%
ml.Total.unique()
# Out:
# array([  315,   683,  1010,   508,    76,    35,   248,     2,     8,
#          624,    29,   119,    49,  1464,  1877,    41,   703,  2304,
#          289,    50,   226,    90,  2642,  2955,     5,   654,   483,
#          693,   172,   468,   233,   133,   152,  2336,    40,  2026,
#         2332,  2878,    46,    36,   242,   130,   228,   147,    78,
#           14,   150,    93,  1240,   231,  3003,    99,   154,    48,
#          243,    17,    82,   167,     6,  1593,     9,   140,   622,
#           68,  6469,  4990,   403,  2638,   438,  2128,   115,   128,
#          283,  1607,   457,    91,   533,  2159,    70,   260,   877,
#           38,    12,     3,  1032,   716,  1747,  3542,   639,    44,
#         1405,    30,   164,   605,    73,     1,   132,    34,  2881,
#          101,    65,  2903,     4,   117,  2229,    39,  2281,  1354,
#           37,   155,   669,  1414,    42,  2725,  2386,  3767,    75,
# ...

# %%
ml.Scheduled.unique()
# Out:
# array([0])

# %%
ml.interpolate()
# Out:
#        data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0    05-01-2014  2014      5       14492     RDU       36      11032    CUN
# 1    06-01-2007  2007      6       13204     MCO       33      16085    YHZ
# 2    12-01-2005  2005     12       11433     DTW       43      10411    AUA
# 3    04-01-2003  2003      4       13487     MSP       63      16304    ZIH
# 4    12-01-2005  2005     12       12016     GUM        5      11138    CRK
# ..          ...   ...    ...         ...     ...      ...        ...    ...
# 995  06-01-2003  2003      6       11423     DSM       61      16217    YUL
# 996  12-01-2006  2006     12       11433     DTW       43      16257    YYC
# 997  04-01-2005  2005      4       13495     MSY       72      11032    CUN
# 998  02-01-2001  2001      2       13930     ORD       41      13605    NAS
# 999  04-01-2001  2001      4       13303     MIA       33      14739    SDQ
#
# ...

# %%
ml.isnull().sum()
# Out:
# data_dte         0
# Year             0
# Month            0
# usg_apt_id       0
# usg_apt          0
# usg_wac          0
# fg_apt_id        0
# fg_apt           0
# fg_wac           0
# airlineid        0
# carrier         18
# carriergroup     0
# type             0
# Scheduled        0
# Charter          0
# Total            0
# dtype: int64

# %%
ml.tail()
# Out:
#        data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 995  06-01-2003  2003      6       11423     DSM       61      16217    YUL
# 996  12-01-2006  2006     12       11433     DTW       43      16257    YYC
# 997  04-01-2005  2005      4       13495     MSY       72      11032    CUN
# 998  02-01-2001  2001      2       13930     ORD       41      13605    NAS
# 999  04-01-2001  2001      4       13303     MIA       33      14739    SDQ
#
#      fg_wac  airlineid carrier  carriergroup        type  Scheduled  Charter  \
# 995     941      19531      AC             0  Passengers          0       52
# 996     916      20305     PCQ             1  Passengers          0       43
# 997     148      20402      GL             1  Passengers          0      160
# 998     204      20344     RYQ             1  Passengers          0     1207
# 999     224      20016     LGQ             0  Passengers          0     2844
#
#      Total
# 995     52
# 996     43
# ...

# %%
#PLOTTING
import matplotlib.pyplot as plt

# %%
plt.scatter(ml.Year,ml.Month)
plt.scatter(ml.Month,ml.fg_wac)
plt.legend(["x-Year","y-Month"],loc="lower right")
plt.show()

# %%
#HISTOGRAM
plt.hist(ml.carriergroup)
plt.legend(['charter'],loc='upper left')

# %%
plt.plot(ml.airlineid,ml.carriergroup)
plt.legend(["x-airline"],loc='upper right')

# %%
 #BAR CHART
 plt.bar(ml.usg_wac,ml.fg_apt_id,color='B')
 plt.title("PASSENGERS")
 plt.legend(["x-usg_wac","y-fg_apt_id"])
 plt.show()

# %%
plt.stem(ml.Charter)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.

# %%
#POLAR FORM
plt.polar(ml.fg_apt_id)
plt.show()

# %%
pie=ml.Year
plt.pie(pie)
plt.show()
